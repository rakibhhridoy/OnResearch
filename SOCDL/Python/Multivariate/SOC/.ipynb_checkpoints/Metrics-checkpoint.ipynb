# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_metrics(epochs):
    fname = f"epochs{epochs}/metrics.csv"
    metrics = pd.read_csv(fname)
    return metrics

# %%
epochs = 50

# %%
ep100 = load_metrics(epochs)
ep100
# Out:
#     Metrics Model Category         Model         y
# 0       NSE        General           CNN  0.455450
# 1       NSE        General           RNN  0.503996
# 2       NSE        General           GRU -0.566404
# 3       NSE        General          LSTM -0.539574
# 4       NSE             MA           CNN  0.231763
# ..      ...            ...           ...       ...
# 107      R2          MA HY  LSTM RNN GRU -0.313677
# 108      R2          MA HY   CNN RNN GRU -0.240672
# 109      R2          MA HY       CNN GRU -0.429941
# 110      R2          MA HY       RNN GRU -0.392950
# 111      R2          MA HY      RNN LSTM -0.406285
#
# [112 rows x 4 columns]

# %%
ep100.plot()
# Out:
# <Axes: >

# %%
sns.barplot(ep100, x= "Model Category", y="Metrics", hue= "Model", palette= "Dark2")
# Out:
# <Axes: xlabel='Model Category', ylabel='Metrics'>
